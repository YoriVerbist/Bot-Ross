# %%
# !pip install Google-Images-Search
# Out:
# ...
#      |████████████████████████████████| 865 kB 3.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 61 kB 63 kB/s s eta 0:00:01
# ...
#   Using cached termcolor-1.1.0.tar.gz (3.9 kB)
# ...
#      |████████████████████████████████| 2.1 MB 4.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 91 kB 8.6 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 114 kB 11.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 95 kB 5.7 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 100 kB 9.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.0 MB 10.2 MB/s eta 0:00:01
# ...
#   Using cached rsa-4.6-py3-none-any.whl (47 kB)
# ...
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# ...
#   Using cached cachetools-4.1.1-py3-none-any.whl (10 kB)
# ...
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# ...
#   ERROR: Command errored out with exit status 1:
# ...

# %%
from google_images_search import GoogleImagesSearch

# %%
gis = GoogleImagesSearch(api-key, project_cx)
painters = ['van gogh', 'da vinci', 'cezanne', 'monet', 'dali', 'picasso']
i = 0

for painter in painters:
    # define search params:
    _search_params = {
        'q': f'{painter} paintings',
        'num': 100,
    }
    i += 1

    # this will search, download and resize:
    gis.search(search_params=_search_params, path_to_dir=f'/resources/{painter}', width=500, height=500, custom_image_name=f'{painter}{i}')
# Out:
# Exception in thread Thread-53:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yori/Documents/School/3ITF/DL/envs/paintings/lib/python3.8/site-packages/google_images_search/fetch_resize_save.py", line 207, in _download_and_resize
#     image.download(path_to_dir)
#   File "/home/yori/Documents/School/3ITF/DL/envs/paintings/lib/python3.8/site-packages/google_images_search/fetch_resize_save.py", line 367, in download
#     self._path = self._fetch_resize_save.download(self._url, path_to_dir)
#   File "/home/yori/Documents/School/3ITF/DL/envs/paintings/lib/python3.8/site-packages/google_images_search/fetch_resize_save.py", line 232, in download
#     os.makedirs(path_to_dir)
#   File "/usr/lib/python3.8/os.py", line 213, in makedirs
#     makedirs(head, exist_ok=exist_ok)
# ...
